# %%
import debug
# Out:
# > d:\a\pytorch\chapter6\debug.py(29)<module>()
#      28
# ---> 29 x=[1,2,3,4,5]
#      30 r=sum(x)
#
# ipdb> n
# > d:\a\pytorch\chapter6\debug.py(30)<module>()
#      29 x=[1,2,3,4,5]
# ---> 30 r=sum(x)
#      31 r=mul(x)
#
# ipdb> s
# --Call--
# > d:\a\pytorch\chapter6\debug.py(12)sum()
#      11
# ---> 12 def sum(x):
#      13     r=0
#
# ipdb> n
# > d:\a\pytorch\chapter6\debug.py(13)sum()
#      12 def sum(x):
# ---> 13     r=0
#      14     for ii in x:
#
# ipdb> n
# > d:\a\pytorch\chapter6\debug.py(14)sum()
#      13     r=0
# ---> 14     for ii in x:
#      15         r += ii
#
# ipdb> n
# > d:\a\pytorch\chapter6\debug.py(15)sum()
#      14     for ii in x:
# ---> 15         r += ii
#      16
#
# ipdb> u #up的缩写，跳回上一层
# *** Invalid frame count (#up的缩写，跳回上一层)
# ipdb> u
# > d:\a\pytorch\chapter6\debug.py(30)<module>()
#      29 x=[1,2,3,4,5]
# ---> 30 r=sum(x)
#      31 r=mul(x)
#
# ipdb> d
# > d:\a\pytorch\chapter6\debug.py(15)sum()
#      14     for ii in x:
# ...
